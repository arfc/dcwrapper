# %%
import numpy as np
import pandas as pd
import os
import sys
sys.path.append('../../../scripts')
import output as oup
import results_analysis as ra
import matplotlib.pyplot as plt
from matplotlib import cm

# %%
# Absolute values of output variables associated with proliferation evaluation metric for each scenario 
df = ra.format_dataframe(dat_file='fs-ty.dat',
                    column_names=['id','Fleetshare', 'Transition Year','HLW','Depleted U','Idle Capacity'],
                    index=['Fleetshare','Transition Year'])
df
# Out:
#                                     HLW   Depleted U Idle Capacity
# Fleetshare Transition Year
# 0          960               13153061.6  798818620.4   135.0833333
# 5          960              13056988.69  798818620.4   135.0833333
# 10         960              13051896.33  798818620.4   135.0833333
# 15         960               12959554.6  798818620.4   135.0833333
# 20         960              13002121.69  798818620.4   135.0833333
# 0          972              13156029.76  798818620.4     124.89566
# 5          972              13083988.93  798818620.4     121.89566
# 10         972              13044738.44  798818620.4   120.9374933
# 15         972              13069176.95  798818620.4   120.9374933
# 20         972              13017098.82  798818620.4   120.9374933
# 0          984              12465564.35  803332630.7     121.77082
# 5          984              13227032.01  803332630.7     121.10416
# 10         984              13232394.26  803332630.7     121.10416
# ...

# %%
# Maximum HLW for each scenario
ra.threed_plot(df,'HLW',True)

# %%
# Maximum Dep U for each scenario
ra.threed_plot(df,'Depleted U',False)

# %%
# Maximum Dep U for each scenario
ra.threed_plot(df,'Idle Capacity',True)
